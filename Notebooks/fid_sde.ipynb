# %%
# %%capture
# !pip install pytorch-fid

# %%
# %%capture
# !pip install datasets

# %%
import os
import math
import glob
import zipfile
import random
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

from os import path
from PIL import Image
from tqdm.auto import tqdm
from pathlib import Path
from numpy.random import seed
from google.colab import drive
from datasets import load_dataset
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision.io import read_image

# %%
random_seed = 42

seed(random_seed)
random.seed(random_seed)

# %%
# %%capture
drive.mount('/content/gdrive', force_remount=True)
with zipfile.ZipFile("/content/gdrive/MyDrive/Progetto_AML/Datasets/CelebA-HQ-256.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
base_dir_256 = "/content/celeba_hq_256/"

# %%
with zipfile.ZipFile("/content/gdrive/MyDrive/Progetto_AML/Datasets/sde_inference_results.zip","r") as zip_ref:
    zip_ref.extractall()

# %%
# !python -m pytorch_fid "/content/celeba_hq_256" "/content/sde_inference_results" --dims 2048
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 69.5MB/s]
# 100% 600/600 [02:21<00:00,  4.25it/s]
# 100% 2/2 [00:00<00:00,  2.73it/s]
# FID:  63.51353543996473

# %%
# %%capture
# !pip install diffusers

# %%
# %%capture
# !pip install accelerate

# %%
from PIL import Image
from tqdm.auto import tqdm
from google.colab import drive

from diffusers import ScoreSdeVeScheduler
from diffusers import ScoreSdeVePipeline

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
N_IMAGES = 10
model_id = "google/ncsnpp-celebahq-256"
sde_ve = ScoreSdeVePipeline.from_pretrained(model_id)
sde_ve.to("cuda")
# Out:
# ...
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# ...
# ScoreSdeVePipeline {
#   "_class_name": "ScoreSdeVePipeline",
#   "_diffusers_version": "0.12.1",
#   "scheduler": [
#     "diffusers",
#     "ScoreSdeVeScheduler"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DModel"
#   ]
# }

# %%
for i in tqdm(range(N_IMAGES)):
  image = sde_ve()
  image_name = "image_" + str(i+66) + ".jpg"
  path = "/content/gdrive/MyDrive/sde_images/" + image_name
  image.images[0].save(path)
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]

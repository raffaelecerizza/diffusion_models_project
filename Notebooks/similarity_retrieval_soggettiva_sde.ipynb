# %%
import os
import re
import cv2
import shutil
import random
import tarfile
import zipfile
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from numpy.random import seed
from google.colab import drive
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import mixed_precision
from tensorflow.keras import regularizers
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from keras.utils import dataset_utils
from keras.preprocessing.image import ImageDataGenerator

from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import top_k_accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
random_seed = 42

seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# %%
drive.mount('/content/gdrive', force_remount=True)
with zipfile.ZipFile("/content/gdrive/MyDrive/Progetto_AML/Datasets/CelebA-HQ-256.zip","r") as zip_ref:
    zip_ref.extractall()  
with zipfile.ZipFile("/content/gdrive/MyDrive/Progetto_AML/Datasets/sde_inference_results.zip","r") as zip_ref:
    zip_ref.extractall()
# Out:
# Mounted at /content/gdrive

# %%
image_size = (299, 299)  # per InceptionV3

# %%
real_data_dir = pathlib.Path('/content/celeba_hq_256/')
seed_ds = 42 
shuffle_value = False
batch_size = 1

real_ds = tf.keras.preprocessing.image_dataset_from_directory(
    real_data_dir,
    labels=None,
    seed=seed_ds,
    image_size=image_size,
    batch_size=batch_size,
    shuffle=shuffle_value)
# Out:
# Found 30000 files belonging to 1 classes.

# %%
sde_data_dir = pathlib.Path('/content/sde_inference_results/')
seed_ds = 42 
shuffle_value = False
batch_size = 1

sde_ds = tf.keras.preprocessing.image_dataset_from_directory(
    sde_data_dir,
    labels=None,
    seed=seed_ds,
    image_size=image_size,
    batch_size=batch_size,
    shuffle=shuffle_value)
# Out:
# Found 100 files belonging to 1 classes.

# %%
image_real = image.load_img("/content/celeba_hq_256/00000.jpg", target_size=image_size)
image_real
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FDDD7540EE0>

# %%
image_sde = image.load_img("/content/sde_inference_results/image_0.jpg", target_size=image_size)
image_sde
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FDE7002A7F0>

# %%
def preprocess(images):
  return preprocess_input(images)

real_ds_preprocessed = real_ds.map(preprocess)
sde_ds_preprocessed = sde_ds.map(preprocess)

# %% [markdown]
# # Creazione modello

# %%
model = InceptionV3(weights='imagenet')
model.summary()
# Out:
# ...
# 96112376/96112376 [==============================] - 1s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
# ...

# %%
for layer in model.layers:
  layer.trainable = False

feat_extractor_model = Model(inputs=model.input, 
                             outputs=model.get_layer('avg_pool').output)
feat_extractor_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
features_real_data = feat_extractor_model.predict(real_ds_preprocessed)
print(features_real_data.shape)
# Out:
# 30000/30000 [==============================] - 472s 15ms/step
# (30000, 2048)

# %%
paths = real_ds.file_paths

# %%
knn = NearestNeighbors(n_neighbors=5, 
                       algorithm='brute',
                       metric='minkowski',
                       p=2)
knn.fit(features_real_data)
# Out:
# NearestNeighbors(algorithm='brute')

# %% [markdown]
# # Valutazione soggettiva similarity retrieval per SDE

# %%
#features_sde_data = feat_extractor_model.predict(sde_ds_preprocessed)
#print(features_sde_data.shape)

# %%
img_path = "/content/sde_inference_results/image_4.jpg"
img = image.load_img(img_path, target_size=image_size)
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = preprocess_input(img)

im_query = image.load_img(img_path, target_size=image_size)
im_query
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7FDDD6499D60>

# %%
features_new_image = feat_extractor_model.predict(img)
print(features_new_image.shape)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# (1, 2048)

# %%
features_new_image
# Out:
# array([[0.2922404 , 0.32338896, 0.16081297, ..., 0.4951929 , 0.23404962,
#         0.39732397]], dtype=float32)

# %%
# Il primo array indica le distanze
# Il secondo array specifica gli indici delle immagini recuperate
closest_distances, indices = knn.kneighbors(features_new_image, n_neighbors=5)

for i in range(5):
  path_plot = paths[indices[0,i]]
  
  img = image.load_img(path_plot, target_size=image_size)

  plt.figure()
  plt.title(indices[0,i])
  plt.imshow(img)
  plt.axis('off')
